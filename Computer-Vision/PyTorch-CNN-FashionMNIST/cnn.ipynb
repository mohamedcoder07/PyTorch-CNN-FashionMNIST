# %% [markdown]
# # PyTorch tutorial

# %% [markdown]
# This notebook serves as a hands-on ***tutorial*** designed for individuals who want to explore and better understand ***PyTorch***. In particular, we will focus on its application in ***computer vision***, demonstrating how to build and train models for image classification tasks.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import partial
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Subset, random_split#, TensorDataset
from torch import optim

from torchvision import datasets
import torchvision.models as models
import torchvision.transforms as T

from model import Model_cnn, train_eval_model

# %% [markdown]
# **Most important points to explore :**
#
# - Loading Data and Devices
# - Autograd
# - Optimizer
# - Loss
# - Model
# - DataLoader
# - Split
# - Saving/Loading Weights
# - Evaluation
# - Visualization

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# # Importing dataset
#
# In this notebook, we will use the **FashionMNIST** dataset available in the **torchvision** package. This dataset consists of grayscale images of Zalando’s fashion articles, such as shoes, shirts, and bags. It is commonly used as a benchmark for image classification tasks.

# %%
train_transform = T.Compose([
    T.ToTensor(),
    # T.Normalize(mean=[0.5], std=[0.5])
])

# %%
train = datasets.FashionMNIST(
    root="data", 
    train=True,
    download=True, 
    transform=train_transform, 
    target_transform=None
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=T.ToTensor()
)

# %%
# train_data, val_data = random_split(train, [len(train_idx), len(val_idx)])

# len_img=len(train)
# len_train=int(0.85*len_img)
# len_val=len_img-len_train
# len_test=len(test_data)

# %%
train_idx, val_idx = train_test_split(
    range(len(train)),
    test_size=0.1,
    stratify=[int(elt[1]) for elt in train],
    random_state=42
)


print(f'Training dataset size : {len(train_idx)}')
print(f'Validation dataset size : {len(val_idx)}')
print(f'Test dataset size : {len(test_data)}')
# Out:
# Training dataset size : 54000
# Validation dataset size : 6000
# Test dataset size : 10000

# %%
train_data = Subset(train, train_idx)
val_data = Subset(train, val_idx)

# %%
class_names = train_data.dataset.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
from collections import Counter

def class_distribution(subset, name):

    if hasattr(subset, "dataset") and hasattr(subset.dataset, "targets"):
        labels = [int(subset.dataset.targets[i]) for i in subset.indices]
    else:
        labels = [int(i) for i in subset.targets]

    counter = Counter(labels)       

    print(f'----------------------------\n{name}\n----------------------------')

    for i in np.unique(labels):
        count = counter[i]
        percentage = (count/len(labels))*100
        print(f'{class_names[i]} : {percentage:.2f} %')

# %%
class_distribution(train_data, "Training dataset")
# Out:
# ----------------------------
# Training dataset
# ----------------------------
# T-shirt/top : 10.00 %
# Trouser : 10.00 %
# Pullover : 10.00 %
# Dress : 10.00 %
# Coat : 10.00 %
# Sandal : 10.00 %
# Shirt : 10.00 %
# Sneaker : 10.00 %
# Bag : 10.00 %
# Ankle boot : 10.00 %

# %%
class_distribution(val_data, "Validation dataset")
# Out:
# ----------------------------
# Validation dataset
# ----------------------------
# T-shirt/top : 10.00 %
# Trouser : 10.00 %
# Pullover : 10.00 %
# Dress : 10.00 %
# Coat : 10.00 %
# Sandal : 10.00 %
# Shirt : 10.00 %
# Sneaker : 10.00 %
# Bag : 10.00 %
# Ankle boot : 10.00 %

# %%
class_distribution(test_data, "Test dataset")
# Out:
# ----------------------------
# Test dataset
# ----------------------------
# T-shirt/top : 10.00 %
# Trouser : 10.00 %
# Pullover : 10.00 %
# Dress : 10.00 %
# Coat : 10.00 %
# Sandal : 10.00 %
# Shirt : 10.00 %
# Sneaker : 10.00 %
# Bag : 10.00 %
# Ankle boot : 10.00 %

# %%
from PIL import Image, ImageOps

img_idx = torch.randint(0, len(train_data), (1,))[0]
img_tensor, label = train_data[img_idx]
to_pil = T.ToPILImage()
img = to_pil(img_tensor)
class_name = class_names[label]

plt.figure(figsize=(3,3))
plt.imshow(img, cmap="gray")
plt.title(f"Classe : {class_name}", fontsize=14)
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preparing the data

# %% [markdown]
# In deep learning, we typically use the **mini-batch gradient descent** algorithm.
# Therefore, **DataLoaders** are designed to efficiently organize datasets into batches, making it easier to feed data to the model during training.

# %%
batch_size = 32

train_dataloader = DataLoader(train_data,
    batch_size=batch_size,
    shuffle=True
)

val_dataloader = DataLoader(val_data,
    batch_size=batch_size,
    shuffle=True
)

test_dataloader = DataLoader(test_data,
    batch_size=batch_size,
    shuffle=True
)

print(f"Length of train dataloader: {len(train_dataloader)} batches of {batch_size}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {batch_size}")
# Out:
# Length of train dataloader: 1688 batches of 32
# Length of test dataloader: 313 batches of 32

# %% [markdown]
# # Modeling

# %% [markdown]
# Convolutional Neural Networks (CNNs) are one of the fundamental architectures in computer vision. A typical CNN architecture is composed of ***two main parts***:
#
# 1. ***Convolutional layers*** – These layers are responsible for feature extraction.
# They apply convolutional filters to the input image to detect patterns such as edges, textures, or more complex shapes in deeper layers.
#
# 2. ***Fully connected layers*** – These layers act as the “classifier” part of the network.
# They take the high-level features extracted by the convolutional layers and use them to make predictions, such as identifying the class of an image.

# %% [markdown]
# <p align="center">
#     <img src="pytorch_cnn_lenet.jpg" width="750">
# </p>

# %%
from torchsummary import summary

model = Model_cnn(len(class_names)).to(device=device)
summary(model, input_size=(1, 28, 28), device=device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 25, 25]             544
#          MaxPool2d-2           [-1, 32, 12, 12]               0
#             Conv2d-3             [-1, 64, 9, 9]          32,832
#          MaxPool2d-4             [-1, 64, 4, 4]               0
#             Linear-5                  [-1, 300]         307,500
#               ReLU-6                  [-1, 300]               0
#            Dropout-7                  [-1, 300]               0
#             Linear-8                   [-1, 10]           3,010
# ================================================================
# Total params: 343,886
# Trainable params: 343,886
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.24
# Params size (MB): 1.31
# Estimated Total Size (MB): 1.56
# ----------------------------------------------------------------

# %%
len(val_dataloader.dataset)
# Out:
# 6000

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-4)
loss_fn = nn.CrossEntropyLoss()
num_epochs = 15
model, train_losses, val_losses, train_accs, val_accs = train_eval_model(model, train_dataloader, val_dataloader, num_epochs, optimizer, loss_fn, device,   verbose = True)
# Out:
# ----------------------------------
# Epoch [1/15]
# ----------------------------------
# train loss : 2.29, train acc : 0.16 % [0/1688]
# train loss : 0.76, train acc : 0.75 % [200/1688]
# train loss : 0.67, train acc : 0.75 % [400/1688]
# train loss : 0.85, train acc : 0.59 % [600/1688]
# train loss : 0.56, train acc : 0.81 % [800/1688]
# train loss : 0.43, train acc : 0.84 % [1000/1688]
# train loss : 0.66, train acc : 0.72 % [1200/1688]
# train loss : 0.49, train acc : 0.81 % [1400/1688]
# train loss : 0.79, train acc : 0.66 % [1600/1688]
#
# Avg Train Loss: 0.73, Train Acc : 73.82 % | Avg Val Loss: 0.53 , Val Acc : 80.92 %
# ----------------------------------
# Epoch [2/15]
# ----------------------------------
# train loss : 0.62, train acc : 0.78 % [0/1688]
# train loss : 0.65, train acc : 0.78 % [200/1688]
# train loss : 0.67, train acc : 0.75 % [400/1688]
# train loss : 0.33, train acc : 0.88 % [600/1688]
# train loss : 0.64, train acc : 0.78 % [800/1688]
# train loss : 0.53, train acc : 0.81 % [1000/1688]
# train loss : 0.47, train acc : 0.84 % [1200/1688]
# train loss : 0.56, train acc : 0.81 % [1400/1688]
# train loss : 0.34, train acc : 0.84 % [1600/1688]
#
# Avg Train Loss: 0.61, Train Acc : 81.93 % | Avg Val Loss: 0.48 , Val Acc : 84.38 %
# ----------------------------------
# Epoch [3/15]
# ----------------------------------
# train loss : 0.54, train acc : 0.69 % [0/1688]
# train loss : 0.52, train acc : 0.88 % [200/1688]
# train loss : 0.42, train acc : 0.84 % [400/1688]
# train loss : 0.42, train acc : 0.78 % [600/1688]
# train loss : 0.51, train acc : 0.72 % [800/1688]
# train loss : 0.93, train acc : 0.75 % [1000/1688]
# train loss : 0.49, train acc : 0.75 % [1200/1688]
# train loss : 0.40, train acc : 0.84 % [1400/1688]
# train loss : 0.41, train acc : 0.84 % [1600/1688]
#
# Avg Train Loss: 0.55, Train Acc : 84.37 % | Avg Val Loss: 0.45 , Val Acc : 86.47 %
# ----------------------------------
# Epoch [4/15]
# ----------------------------------
# train loss : 0.35, train acc : 0.91 % [0/1688]
# train loss : 0.59, train acc : 0.75 % [200/1688]
# train loss : 0.31, train acc : 0.88 % [400/1688]
# train loss : 0.40, train acc : 0.84 % [600/1688]
# train loss : 0.28, train acc : 0.88 % [800/1688]
# train loss : 0.50, train acc : 0.78 % [1000/1688]
# train loss : 0.45, train acc : 0.81 % [1200/1688]
# train loss : 0.29, train acc : 0.91 % [1400/1688]
# train loss : 0.65, train acc : 0.81 % [1600/1688]
#
# Avg Train Loss: 0.51, Train Acc : 85.75 % | Avg Val Loss: 0.42 , Val Acc : 86.53 %
# ----------------------------------
# Epoch [5/15]
# ----------------------------------
# train loss : 0.33, train acc : 0.88 % [0/1688]
# train loss : 0.41, train acc : 0.84 % [200/1688]
# train loss : 0.39, train acc : 0.81 % [400/1688]
# train loss : 0.16, train acc : 0.94 % [600/1688]
# train loss : 0.21, train acc : 0.91 % [800/1688]
# train loss : 0.32, train acc : 0.88 % [1000/1688]
# train loss : 0.26, train acc : 0.88 % [1200/1688]
# train loss : 0.39, train acc : 0.88 % [1400/1688]
# train loss : 0.27, train acc : 0.84 % [1600/1688]
#
# Avg Train Loss: 0.48, Train Acc : 86.90 % | Avg Val Loss: 0.40 , Val Acc : 88.23 %
# ----------------------------------
# Epoch [6/15]
# ----------------------------------
# train loss : 0.31, train acc : 0.97 % [0/1688]
# train loss : 0.34, train acc : 0.88 % [200/1688]
# train loss : 0.41, train acc : 0.84 % [400/1688]
# train loss : 0.22, train acc : 0.97 % [600/1688]
# train loss : 0.30, train acc : 0.88 % [800/1688]
# train loss : 0.30, train acc : 0.91 % [1000/1688]
# train loss : 0.23, train acc : 0.94 % [1200/1688]
# train loss : 0.23, train acc : 0.88 % [1400/1688]
# train loss : 0.17, train acc : 0.91 % [1600/1688]
#
# Avg Train Loss: 0.46, Train Acc : 87.58 % | Avg Val Loss: 0.39 , Val Acc : 88.58 %
# ----------------------------------
# Epoch [7/15]
# ----------------------------------
# train loss : 0.42, train acc : 0.81 % [0/1688]
# train loss : 0.34, train acc : 0.88 % [200/1688]
# train loss : 0.23, train acc : 0.94 % [400/1688]
# train loss : 0.15, train acc : 0.97 % [600/1688]
# train loss : 0.63, train acc : 0.78 % [800/1688]
# train loss : 0.08, train acc : 0.97 % [1000/1688]
# train loss : 0.39, train acc : 0.88 % [1200/1688]
# train loss : 0.46, train acc : 0.84 % [1400/1688]
# train loss : 0.17, train acc : 0.94 % [1600/1688]
#
# Avg Train Loss: 0.44, Train Acc : 88.11 % | Avg Val Loss: 0.38 , Val Acc : 88.02 %
# ----------------------------------
# Epoch [8/15]
# ----------------------------------
# train loss : 0.28, train acc : 0.91 % [0/1688]
# train loss : 0.15, train acc : 0.94 % [200/1688]
# train loss : 0.21, train acc : 0.94 % [400/1688]
# train loss : 0.56, train acc : 0.75 % [600/1688]
# train loss : 0.24, train acc : 0.91 % [800/1688]
# train loss : 0.33, train acc : 0.81 % [1000/1688]
# train loss : 0.24, train acc : 0.88 % [1200/1688]
# train loss : 0.23, train acc : 0.94 % [1400/1688]
# train loss : 0.31, train acc : 0.84 % [1600/1688]
#
# Avg Train Loss: 0.42, Train Acc : 88.64 % | Avg Val Loss: 0.37 , Val Acc : 89.05 %
# ----------------------------------
# Epoch [9/15]
# ----------------------------------
# train loss : 0.26, train acc : 0.91 % [0/1688]
# train loss : 0.52, train acc : 0.88 % [200/1688]
# train loss : 0.39, train acc : 0.84 % [400/1688]
# train loss : 0.39, train acc : 0.78 % [600/1688]
# train loss : 0.30, train acc : 0.91 % [800/1688]
# train loss : 0.11, train acc : 0.97 % [1000/1688]
# train loss : 0.33, train acc : 0.94 % [1200/1688]
# train loss : 0.15, train acc : 0.97 % [1400/1688]
# train loss : 0.16, train acc : 0.94 % [1600/1688]
#
# Avg Train Loss: 0.41, Train Acc : 89.04 % | Avg Val Loss: 0.36 , Val Acc : 89.65 %
# ----------------------------------
# Epoch [10/15]
# ----------------------------------
# train loss : 0.20, train acc : 0.97 % [0/1688]
# train loss : 0.48, train acc : 0.88 % [200/1688]
# train loss : 0.24, train acc : 0.91 % [400/1688]
# train loss : 0.63, train acc : 0.81 % [600/1688]
# train loss : 0.42, train acc : 0.78 % [800/1688]
# train loss : 0.39, train acc : 0.81 % [1000/1688]
# train loss : 0.28, train acc : 0.84 % [1200/1688]
# train loss : 0.23, train acc : 0.97 % [1400/1688]
# train loss : 0.32, train acc : 0.91 % [1600/1688]
#
# Avg Train Loss: 0.40, Train Acc : 89.52 % | Avg Val Loss: 0.35 , Val Acc : 89.88 %
# ----------------------------------
# Epoch [11/15]
# ----------------------------------
# train loss : 0.21, train acc : 0.88 % [0/1688]
# train loss : 0.67, train acc : 0.81 % [200/1688]
# train loss : 0.11, train acc : 0.97 % [400/1688]
# train loss : 0.33, train acc : 0.91 % [600/1688]
# train loss : 0.32, train acc : 0.91 % [800/1688]
# train loss : 0.35, train acc : 0.91 % [1000/1688]
# train loss : 0.20, train acc : 0.88 % [1200/1688]
# train loss : 0.34, train acc : 0.81 % [1400/1688]
# train loss : 0.21, train acc : 0.94 % [1600/1688]
#
# Avg Train Loss: 0.38, Train Acc : 89.71 % | Avg Val Loss: 0.35 , Val Acc : 90.15 %
# ----------------------------------
# Epoch [12/15]
# ----------------------------------
# train loss : 0.11, train acc : 0.97 % [0/1688]
# train loss : 0.20, train acc : 0.94 % [200/1688]
# train loss : 0.21, train acc : 0.97 % [400/1688]
# train loss : 0.21, train acc : 0.94 % [600/1688]
# train loss : 0.14, train acc : 0.94 % [800/1688]
# train loss : 0.08, train acc : 0.97 % [1000/1688]
# train loss : 0.18, train acc : 0.94 % [1200/1688]
# train loss : 0.10, train acc : 0.97 % [1400/1688]
# train loss : 0.25, train acc : 0.94 % [1600/1688]
#
# Avg Train Loss: 0.38, Train Acc : 89.93 % | Avg Val Loss: 0.34 , Val Acc : 90.13 %
# ----------------------------------
# Epoch [13/15]
# ----------------------------------
# train loss : 0.18, train acc : 0.94 % [0/1688]
# train loss : 0.14, train acc : 0.97 % [200/1688]
# train loss : 0.20, train acc : 0.97 % [400/1688]
# train loss : 0.29, train acc : 0.94 % [600/1688]
# train loss : 0.31, train acc : 0.91 % [800/1688]
# train loss : 0.25, train acc : 0.91 % [1000/1688]
# train loss : 0.20, train acc : 0.97 % [1200/1688]
# train loss : 0.18, train acc : 0.94 % [1400/1688]
# train loss : 0.32, train acc : 0.88 % [1600/1688]
#
# Avg Train Loss: 0.37, Train Acc : 90.47 % | Avg Val Loss: 0.34 , Val Acc : 90.40 %
# ----------------------------------
# Epoch [14/15]
# ----------------------------------
# train loss : 0.30, train acc : 0.91 % [0/1688]
# train loss : 0.35, train acc : 0.91 % [200/1688]
# train loss : 0.20, train acc : 0.91 % [400/1688]
# train loss : 0.30, train acc : 0.88 % [600/1688]
# train loss : 0.21, train acc : 0.88 % [800/1688]
# train loss : 0.27, train acc : 0.88 % [1000/1688]
# train loss : 0.18, train acc : 0.94 % [1200/1688]
# train loss : 0.33, train acc : 0.91 % [1400/1688]
# train loss : 0.32, train acc : 0.94 % [1600/1688]
#
# Avg Train Loss: 0.36, Train Acc : 90.67 % | Avg Val Loss: 0.33 , Val Acc : 90.43 %
# ----------------------------------
# Epoch [15/15]
# ----------------------------------
# train loss : 0.06, train acc : 1.00 % [0/1688]
# train loss : 0.31, train acc : 0.88 % [200/1688]
# train loss : 0.25, train acc : 0.91 % [400/1688]
# train loss : 0.33, train acc : 0.84 % [600/1688]
# train loss : 0.20, train acc : 0.94 % [800/1688]
# train loss : 0.19, train acc : 0.94 % [1000/1688]
# train loss : 0.37, train acc : 0.88 % [1200/1688]
# train loss : 0.11, train acc : 1.00 % [1400/1688]
# train loss : 0.30, train acc : 0.91 % [1600/1688]
#
# Avg Train Loss: 0.35, Train Acc : 91.04 % | Avg Val Loss: 0.33 , Val Acc : 90.15 %
# Total training time : 26 minutes and 46.01 seconds

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 6))
fig.suptitle('Model performance')

# ====== First plot ======
ax1.plot((np.arange(num_epochs)+1), train_losses, label = 'Train Loss', marker = 'o', color = 'blue')
ax1.plot((np.arange(num_epochs)+1), val_losses, label = 'Validation Loss', marker = 'o', color = 'orange')
ax1.set(xlabel= 'Epochs', ylabel= 'Loss')
ax1.set_title('Loss per epoch')
ax1.legend()
ax1.grid(True, linestyle ='--')


# ====== Second plot ======
ax2.plot((np.arange(num_epochs)+1), train_accs, label = 'Train Accuracy', marker = 'o', color = 'blue')
ax2.plot((np.arange(num_epochs)+1), val_accs, label = 'Validation Accuracy', marker = 'o', color = 'orange')
ax2.set(xlabel= 'Epochs', ylabel= 'Accuracy')
ax2.set_title('Accuracy per epoch')
ax2.legend()
ax2.grid(True, linestyle ='--')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Prediction

# %% [markdown]
# In this section, we collected some clothing images from Google on which we will run predictions using the model trained earlier. It is important that each new image matches the characteristics of the FashionMNIST training images (i.e., grayscale with a black background).

# %% [markdown]
# ## First example test

# %%
trouser_test = Image.open("trouser.jpg").convert("L").resize((28, 28))
trouser_test = ImageOps.invert(trouser_test)
class_name ="Trouser"

plt.figure(figsize=(3,3))
plt.imshow(trouser_test, cmap="gray")
plt.title(f"Classe : {class_name}", fontsize=14)
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
transform = T.Compose([
    T.ToTensor()
])
trouser_tensor = transform(trouser_test)

# %%
scores_img = model(trouser_tensor.unsqueeze(0)) # Each tensor has shape (1, 28, 28), but the model expects a batch dimension. Using unsqueeze adds this extra dimension, giving a final shape of (1, 1, 28, 28).
scores_img
# Out:
# tensor([[ -2.3658,   2.9210,  -2.3912,  -2.9494,  -1.7982,  -4.7361,  -2.1416,
#           -7.4138,  -0.6900, -11.0331]], grad_fn=<AddmmBackward0>)

# %%
pred_img = torch.max(scores_img, 1)
print(pred_img)
# Out:
# torch.return_types.max(
# values=tensor([2.9210], grad_fn=<MaxBackward0>),
# indices=tensor([1]))

# %%
class_names[pred_img.indices]
# Out:
# 'Trouser'

# %% [markdown]
# ## Second example test

# %%
sneaker_test = Image.open("sneaker.jpg").convert("L").resize((28, 28))
sneaker_test = ImageOps.invert(sneaker_test)
class_name ="Sneaker"

plt.figure(figsize=(3,3))
plt.imshow(sneaker_test, cmap="gray")
plt.title(f"Classe : {class_name}", fontsize=14)
plt.axis('off')
plt.tight_layout()
plt.show()

# %%
transform = T.Compose([
    T.ToTensor()
])
sneaker_tensor = transform(sneaker_test)

# %%
scores_img = model(sneaker_tensor.unsqueeze(0))
scores_img
# Out:
# tensor([[ -6.5943, -10.9615,  -7.4428,  -5.0652,  -8.7821,   0.6500,  -8.0452,
#            4.6238,  -5.8355,  -0.6968]], grad_fn=<AddmmBackward0>)

# %%
pred_img = torch.max(scores_img, 1)
print(pred_img)
# Out:
# torch.return_types.max(
# values=tensor([4.6238], grad_fn=<MaxBackward0>),
# indices=tensor([7]))

# %%
class_names[pred_img.indices]
# Out:
# 'Sneaker'
